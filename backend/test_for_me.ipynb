# %%
import src.moex.moex as moex

# %%
data_2 = moex.get_moex_data(engine='stock', 
                            market='shares', 
                            board='TQBR', 
                            seccode='YNDX',
                            end = '2037-12-31 00:00:00',
                            start = '2000-01-01 00:00:00',
                            interval = 24)
data_2
# Out:
#         open   close    high     low         value  volume  \
# 0     1546.7  1170.0  1546.8  1163.0  4.628872e+07   35146
# 1     1187.3  1145.1  1195.0  1141.1  2.892730e+07   24974
# 2     1158.3  1163.0  1173.5  1151.0  9.160131e+06    7889
# 3     1178.9  1172.1  1185.6  1155.7  8.481667e+06    7304
# 4     1178.9  1170.0  1181.0  1160.1  3.768586e+06    3216
# ...      ...     ...     ...     ...           ...     ...
# 2506  4229.0  4222.0  4284.2  4210.6  1.398056e+09  329137
# 2507  4222.0  4125.6  4248.0  4082.8  1.242645e+09  297380
# 2508  4100.6  4102.0  4140.6  4092.0  9.600398e+08  233821
# 2509  3980.0  4048.0  4160.0  3901.0  1.475914e+09  362747
# 2510  4048.0  4071.2  4128.8  4030.0  1.353930e+09  330616
#
#                     begin                  end
# 0     2014-06-04 00:00:00  2014-06-04 23:59:59
# 1     2014-06-05 00:00:00  2014-06-05 23:59:59
# 2     2014-06-06 00:00:00  2014-06-06 23:59:59
# 3     2014-06-09 00:00:00  2014-06-09 23:59:59
# ...

# %%
import os
import importlib.util

def import_models(path):
    for root, dirs, files in os.walk(path):
        if 'models.py' in files:
            models_path = os.path.join(root, 'models.py')
            spec = importlib.util.spec_from_file_location("models", models_path)
            module = importlib.util.module_from_spec(spec)
            spec.loader.exec_module(module)
            print(f"Импортирован: {models_path}")


path_to_src = 'src'
import_models(path_to_src)
